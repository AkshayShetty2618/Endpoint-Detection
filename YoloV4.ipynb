# %%
# %cd '/content/drive/MyDrive/yolo3'
# Out:
# /content/drive/MyDrive/yolo3

# %%
# !nvidia-smi
# Out:
# Tue Apr  5 09:21:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet

# %%
% cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
#!apt update
#!apt-get install libopencv-dev

# %%
# %cd '/content/drive/MyDrive/yolo3'
# Out:
# /content/drive/MyDrive/yolo2

# %%
# !python train/creating-train-and-test-txt-files.py
# !python train/creating-files-data-and-name.py

# %%
# %cd custom_weight/
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# %cd darknet
# Out:
# /content/drive/MyDrive/yolo3/darknet

# %%
# !make

# %%
# %cd '/content/drive/MyDrive/yolo3'
# Out:
# /content/drive/MyDrive/yolo3

# %%
#weight for tiny
# %cd custom_weight/
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29

# %%
# !darknet/darknet detector train train/labelled_data.data darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolo/custom_weight/yolov4.conv.137 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.764375), count: 14, class_loss = 2.899423, iou_loss = 166.397369, total_loss = 169.296799
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.809525), count: 7, class_loss = 0.587318, iou_loss = 25.533144, total_loss = 26.120462
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.000000), count: 1, class_loss = 0.000024, iou_loss = 0.000000, total_loss = 0.000024
#  total_bbox = 4836009, rewritten_bbox = 0.009388 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.817444), count: 14, class_loss = 1.449905, iou_loss = 174.271347, total_loss = 175.721252
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.782128), count: 7, class_loss = 0.596846, iou_loss = 47.885010, total_loss = 48.481857
# ...

# %%
# !chmod +x darknet/darknet

# %%
# !darknet/darknet detector demo train/labelled_data.data darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolo3/backup/yolov4-custom_5000.weights /content/drive/MyDrive/yolo3/test3.avi -out_filename result.avi -ext_output -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
# FPS:43.3 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
# Defect: 34% 	(left_x:  617   top_y:  666   width:  109   height:   63)
#
# FPS:43.4 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:43.3 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:43.5 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:43.1 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:43.3 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
# Defect: 50% 	(left_x:  619   top_y:  671   width:  101   height:   54)
#
# FPS:43.1 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
# Defect: 79% 	(left_x:  165   top_y:  780   width:   94   height:   68)
#
# FPS:43.4 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
# Defect: 89% 	(left_x:  170   top_y:  779   width:   90   height:   71)
# Defect: 54% 	(left_x:  620   top_y:  668   width:  101   height:   61)
#
# FPS:43.0 	 AVG_FPS:44.3
#
#  cvWriteFrame
# Objects:
#
# ...
